# %%
import numpy as np #numpy kütüphanesini np olarak ekler
dizi1=np.array([1,2,3])
dizi2=np.array(["elma","armut","vişne"])

# %%
dizi1
# Out:
# array([1, 2, 3])

# %%
dizi2
# Out:
# array(['elma', 'armut', 'vişne'], dtype='<U5')

# %%
np.array([1,2,3])#NumPy dizisi oluşturmak için
# Out:
# array([1, 2, 3])

# %%
dizi=np.array([1,2,3,3.14],dtype=int)#NumPy dizilerini tanımlama sırasında dizideki tüm elemanları tek tipe dönüştürme işlemi
gerçekleştirilebilir.
dizi
# Out:
# array([1, 2, 3, 3])

# %%
birboyut=np.array([1,2,3])
birboyut
# Out:
# array([1, 2, 3])

# %%
ikiboyut = np.array([[1,2,3], [4,5,6]])#İki boyutlu dizi oluşturmak için
ikiboyut
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
ucboyut= np.array([[[1,2,3], [4,5,6]], [[1,2,3], [4,5,6]]])#Üç boyutlu dizi oluşturmak için
ucboyut
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])
